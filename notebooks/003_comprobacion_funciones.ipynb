# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import xarray as xr 
from datetime import datetime, date, timedelta
import plotly.graph_objects as go
from Tools.funciones import (
    inicializar_datasets,
    convertir_a_celsius,
    convertir_a_hora_local,
    convertir_ssrd,
    grafica_promedio_std,
    grafica_promedio_all,
    heatmap_personalizado,
    heatmap_mes
)

# %%
oaxaca = inicializar_datasets("../data/001_raw/ERA5_Oaxaca_2023.nc")

# %%
oaxaca = convertir_a_celsius(oaxaca, "t2m")

# %%
oaxaca = convertir_a_hora_local(oaxaca, -6)

# %%
oaxaca = convertir_ssrd(oaxaca, "ssrd")

# %%
heatmap_personalizado(oaxaca, f1="2023-01-01", f2="2023-02-01", variable="t2m_Celsius", unidad="°C")
